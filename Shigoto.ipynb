# %%
Kappa = []
Todas = input("Ingrese todo1")
Todas2 = input("Ingrese todo1")
ZEMBU1 = Todas.split("WENAS")
ZEMBU2 = Todas2.split("WENAS")
for x in range(len(ZEMBU1)):
    todo = ZEMBU1[x]
    tablename = todo.split(": ")[0]
    variablesText = todo.split(": ")[1]
    todo2 = ZEMBU2[x]
    llavesText = todo2.split(": ")[1]
    plantilla = "$sqlplantilla=\"select * from plantilla\";\n$rsServerplantilla=mysqli_query($mysqliServer,$sqlplantilla) or die (mysqli_error($mysqli));\n$rsLocalplantilla=mysqli_query($mysqli,$sqlplantilla) or die (mysqli_error($mysqli));\n\nwhile ($rowplantilla= mysqli_fetch_array($rsServerplantilla)) {\n$sqlCheckplantilla = \"select * from plantilla where Kappa1\";\n$rsCheckplantilla=mysqli_query($mysqli,$sqlCheckplantilla) or die (mysqli_error($mysqli));\nif (mysqli_num_rows($rsCheckplantilla)==0){\n$sqlInsertplantilla = \"insert into plantilla (Kappa2) values (Kappa3)\";\nmysqli_query($mysqli,$sqlInsertplantilla) or die (mysqli_error($mysqli));\n}\n}"
    variables = variablesText.split(", ")
    llaves = llavesText.split(", ")
    Kappa1 = ""
    Kappa2 = ""
    Kappa3 = ""
    for llave in range(len(llaves)):
        if llave != 0:
            Kappa1 = Kappa1 + " and "
        Kappa1 = Kappa1 + llaves[llave] + " = \'\".$rowplantilla[\""+llaves[llave]+"\"].\"\'"

    for variable in range(len(variables)):
        if variable != 0:
            Kappa3 = Kappa3 + ","
        Kappa3 = Kappa3 + "\'\".$rowplantilla[\"" + variables[variable] + "\"].\"\'"
    plantilla = plantilla.replace("Kappa1",Kappa1)
    plantilla = plantilla.replace("Kappa2",variablesText)
    plantilla = plantilla.replace("Kappa3",Kappa3)
    plantilla = plantilla.replace("plantilla",tablename)
    Kappa.append(plantilla)
# Out:
# Ingrese todo1aplicadocumento: nro_apli, tip_apli, valor_apli, fecha_apli, recnro_apli, clinit_apli, item_apli, emp_apli, ret_apli, retiva_apli, par_apli, devol_apli, descto_apli, flete_apli, falta_apli, obsdes_apli, obsfle_apli, obsfal_apliWENASbancos: cod_ban, desc_ban, cuenta_ban, titular_ban, elim_ban, dest_ban, cupo_ban, emp_ban, refer_ban, puc_ban, vbanco_ban, bor_banWENAScategoria: cod_ctg, desc_ctg, det_ctgWENASciudad: cod_ciu, desc_ciu, elim_ciu, dep_ciu, dane_ciuWENASclixven: cli_cxv, ven_cxvWENAScodigobarra: ref_bar, talla_bar, cod_bar, oc_bar, num_bar, cant_bar, det_bar, expor_barWENAScondipago: cod_cpg, desc_cpg, det_cpg, porc_cpgWENAScxc: num_cxc, nit_cxc, suc_cxc, val_cxc, abo_cxc, sal_cxc, tip_cxc, empr_cxc, pre_cxc, fec_cxc, fvc_cxcWENASdepartamento: cod_dep, desc_dep, elim_depWENASdocumento: num_dco, tipo_dco, nit_dco, suc_dco, fec_dco, nfa_dco, pla_dco, ffa_dco, fcv_dco, tpr_dco, vtd_dco, desc_dco, imp_dco, tot_dco, anu_dco, obs_dco, fdo_dco, emp_dco, ven_dco, tempo
# ...

# %%
for y in range(len(Kappa)):
    print(Kappa[y])
    print("\n")
# Out:
# $sqlaplicadocumento="select * from aplicadocumento";
# $rsServeraplicadocumento=mysqli_query($mysqliServer,$sqlaplicadocumento) or die (mysqli_error($mysqli));
# $rsLocalaplicadocumento=mysqli_query($mysqli,$sqlaplicadocumento) or die (mysqli_error($mysqli));
#
# while ($rowaplicadocumento= mysqli_fetch_array($rsServeraplicadocumento)) {
# $sqlCheckaplicadocumento = "select * from aplicadocumento where nro_apli = '".$rowaplicadocumento["nro_apli"]."' and tip_apli = '".$rowaplicadocumento["tip_apli"]."' and recnro_apli = '".$rowaplicadocumento["recnro_apli"]."' and clinit_apli = '".$rowaplicadocumento["clinit_apli"]."' and item_apli = '".$rowaplicadocumento["item_apli"]."' and emp_apli = '".$rowaplicadocumento["emp_apli"]."'";
# $rsCheckaplicadocumento=mysqli_query($mysqli,$sqlCheckaplicadocumento) or die (mysqli_error($mysqli));
# if (mysqli_num_rows($rsCheckaplicadocumento)==0){
# ...

# %%
Kappa = []
Kapppa = []
BigBoi = "BigBoi"
Todas = input("Ingrese todo1")
Todas2 = input("Ingrese todo1")
ZEMBU1 = Todas.split("WENAS")
ZEMBU2 = Todas2.split("WENAS")
for x in range(len(ZEMBU1)):
    todo = ZEMBU1[x]
    tablename = todo.split(": ")[0]
    variablesText = todo.split(": ")[1]
    todo2 = ZEMBU2[x]
    llavesText = todo2.split(": ")[1]
    plantilla = "case \"plantilla\":\n        include \"../conexion.php\";\n        $sqlplantilla=\"select * from plantilla\";\n        $rsServerplantilla=mysqli_query($mysqliServer,$sqlplantilla) or die (mysqli_error($mysqli));;\n\n        while ($rowplantilla= mysqli_fetch_array($rsServerplantilla)) {\n            $sqlCheckplantilla = \"select llaves from plantilla where Kappa1\";\n            $rsCheckplantilla=mysqli_query($mysqli,$sqlCheckplantilla) or die (mysqli_error($mysqli));\n\n            if (mysqli_num_rows($rsCheckplantilla)>0){\n                $sqlUpdateplantilla = \"update plantilla set Kappa2 where Kappa1\";\n                mysqli_query($mysqli,$sqlUpdateplantilla) or die (mysqli_error($mysqli));\n            }\n            else{\n                $sqlInsertplantilla = \"insert into plantilla (Kappa4) values (Kappa3)\";\n                mysqli_query($mysqli,$sqlInsertplantilla) or die (mysqli_error($mysqli));\n            }\n        }\n        break;"
    plantilla2 = "$.ajax({\n			url: \"../informes/actualizar.php?table=plantilla\",\n			type: \'get\',\n			success: function(data){\n				$(\"#div_listarcp\").html(data);\n				BigBoi\n			}\n		});"
    variables = variablesText.split(", ")
    llaves = llavesText.split(", ")
    Kappa1 = ""
    Kappa2 = ""
    Kappa3 = ""
    
    for variable in range(len(variables)):
        if variable != 0:
            Kappa3 = Kappa3 + ","
        Kappa3 = Kappa3 + "\'\".$rowplantilla[\"" + variables[variable] + "\"].\"\'"
        
    for llave in range(len(llaves)):
        if llave != 0:
            Kappa1 = Kappa1 + " and "
        Kappa1 = Kappa1 + llaves[llave] + " = \'\".$rowplantilla[\""+llaves[llave]+"\"].\"\'"
        variables.remove(llaves[llave])
    
    for variable in range(len(variables)):
        if variable != 0:
            Kappa2 = Kappa2 + ","
        Kappa2 = Kappa2 + variables[variable] + " = \'\".$rowplantilla[\""+ variables[variable] +"\"].\"\'"
    
    plantilla = plantilla.replace("Kappa1",Kappa1)
    plantilla = plantilla.replace("llaves",llavesText)
    plantilla = plantilla.replace("Kappa2",Kappa2)
    plantilla = plantilla.replace("Kappa4",variablesText)
    plantilla = plantilla.replace("Kappa3",Kappa3)
    plantilla = plantilla.replace("plantilla",tablename)
    plantilla2 = plantilla2.replace("plantilla",tablename)
    Kappa.append(plantilla)
    Kapppa.append(plantilla2)
    BigBoi = BigBoi.replace("BigBoi",plantilla2)
# Out:
# Ingrese todo1aplicadocumento: nro_apli, tip_apli, valor_apli, fecha_apli, recnro_apli, clinit_apli, item_apli, emp_apli, ret_apli, retiva_apli, par_apli, devol_apli, descto_apli, flete_apli, falta_apli, obsdes_apli, obsfle_apli, obsfal_apliWENASbancos: cod_ban, desc_ban, cuenta_ban, titular_ban, elim_ban, dest_ban, cupo_ban, emp_ban, refer_ban, puc_ban, vbanco_ban, bor_banWENAScatalogoc: ref_cat, col_catWENAScategoria: cod_ctg, desc_ctg, det_ctgWENASciudad: cod_ciu, desc_ciu, elim_ciu, dep_ciu, dane_ciuWENASclixven: cli_cxv, ven_cxvWENAScodigobarra: ref_bar, talla_bar, cod_bar, oc_bar, num_bar, cant_bar, det_bar, expor_barWENAScolor: cod_col, desc_col, elim_colWENAScondipago: cod_cpg, desc_cpg, det_cpg, porc_cpgWENAScxc: num_cxc, nit_cxc, suc_cxc, val_cxc, abo_cxc, sal_cxc, tip_cxc, empr_cxc, pre_cxc, fec_cxc, fvc_cxcWENASdepartamento: cod_dep, desc_dep, elim_depWENASdocumento: num_dco, tipo_dco, nit_dco, suc_dco, fec_dco, nfa_dco, pla_dco, ffa_dco, fcv_dco, tpr_dco, vtd_dco, desc_dc
# ...

# %%
for y in range(len(Kappa)):
    print(Kapppa[y])
    print("\n")
# Out:
# $("#div_listarcp").html('<img src="../css/images/cargando.gif">');
# 		$.ajax({
# 			url: "../informes/actualizar.php?table=aplicadocumento",
# 			type: 'get',
# 			success: function(data){
# 				$("#div_listarcp").html(data);
#
# 			}
# 		});
#
#
# $("#div_listarcp").html('<img src="../css/images/cargando.gif">');
# 		$.ajax({
# 			url: "../informes/actualizar.php?table=bancos",
# 			type: 'get',
# 			success: function(data){
# 				$("#div_listarcp").html(data);
#
# 			}
# 		});
#
#
# $("#div_listarcp").html('<img src="../css/images/cargando.gif">');
# 		$.ajax({
# 			url: "../informes/actualizar.php?table=catalogoc",
# 			type: 'get',
# 			success: function(data){
# 				$("#div_listarcp").html(data);
#
# 			}
# 		});
#
#
# $("#div_listarcp").html('<img src="../css/images/cargando.gif">');
# 		$.ajax({
# 			url: "../informes/actualizar.php?table=categoria",
# 			type: 'get',
# 			success: function(data){
# 				$("#div_listarcp").html(data);
#
# 			}
# 		});
#
#
# ...

# %%
print(BigBoi)
# Out:
# $.ajax({
# 			url: "../informes/actualizar.php?table=aplicadocumento",
# 			type: 'get',
# 			success: function(data){
# 				$("#div_listarcp").html(data);
# 				$.ajax({
# 			url: "../informes/actualizar.php?table=bancos",
# 			type: 'get',
# 			success: function(data){
# 				$("#div_listarcp").html(data);
# 				$.ajax({
# 			url: "../informes/actualizar.php?table=catalogoc",
# 			type: 'get',
# 			success: function(data){
# 				$("#div_listarcp").html(data);
# 				$.ajax({
# 			url: "../informes/actualizar.php?table=categoria",
# 			type: 'get',
# 			success: function(data){
# 				$("#div_listarcp").html(data);
# 				$.ajax({
# 			url: "../informes/actualizar.php?table=ciudad",
# 			type: 'get',
# 			success: function(data){
# 				$("#div_listarcp").html(data);
# 				$.ajax({
# 			url: "../informes/actualizar.php?table=clixven",
# 			type: 'get',
# 			success: function(data){
# 				$("#div_listarcp").html(data);
# 				$.ajax({
# ...
